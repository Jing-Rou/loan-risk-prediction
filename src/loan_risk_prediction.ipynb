# %%
import sys
print(sys.executable)

# %%
import pandas as pd

# %% [markdown]
# ### **Read and Load Datasets from different sources**

# %%
loan_db = pd.read_csv('assets/loan.csv')
loan_db.head()

# %%
load_db.info()

# %%
payment_db = pd.read_csv('assets/payment.csv')
payment_db.head()

# %%
clarity_underwriting_db = pd.read_csv('assets/clarity_underwriting_variables.csv')
clarity_underwriting_db.head()

# %% [markdown]
# ### **Data Preprocessing**
# - Feature Concatenates

# %%
merged_db = loan_db.merge(payment_db, on='loanId', how='left')
merged_db.head()
